# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from FHFData import Kantec2509Dataset

import cv2
import os
import pandas as pd
import torch
from torch import nn as nn
from torch import optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision.io import decode_image
from torchvision.transforms import v2
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
from matplotlib import pyplot as plt
from FHFData import Kantec2509Dataset
from transformers import get_cosine_schedule_with_warmup

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1):
        super().__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        
        # FIX: Replacing GroupNorm with InstanceNorm2d to bypass dimension error
        # InstanceNorm2d applies normalization per-channel and per-instance
        if out_channels > 1: # Only apply if there is more than one channel
            self.norm = nn.InstanceNorm2d(out_channels, affine=True) 
        else:
            self.norm = nn.Identity() 

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        # Contiguity is now less necessary but still safe
        x = self.conv(x).contiguous()
        return self.relu(self.norm(x))

# %%
# Note: This block uses InstanceNorm2d, which was the final working normalization layer.
# The 'reduction_ratio' (r) is a hyperparameter (default 16) controlling the size
# of the fully connected layers in the attention path.

class ResidualBlock(nn.Module):
    def __init__(self, channels, reduction_ratio=16):
        super().__init__()
        
        C = channels # Number of input/output channels

        # --- Main Path Components ---
        # CONV1: Standard 3x3 Conv, followed by InstanceNorm and ReLU
        self.conv1 = nn.Conv2d(C, C, kernel_size=3, stride=1, padding=1)
        self.norm1 = nn.InstanceNorm2d(C, affine=True)
        self.relu = nn.ReLU(inplace=True)
        
        # CONV2: Simplified 1x1 Conv (or 3x3) followed by InstanceNorm
        # Using 1x1 is common to control channel mixing post-attention
        self.conv2 = nn.Conv2d(C, C, kernel_size=1, stride=1, padding=0) 
        self.norm2 = nn.InstanceNorm2d(C, affine=True)

        # --- Squeeze-and-Excitation (SE) Attention Path ---
        # 1. Global Pooling (Squeeze): Reduces (H, W) to (1, 1)
        self.global_pool = nn.AdaptiveAvgPool2d(1)

        # 2. Fully Connected Layers (Excitation)
        reduced_channels = max(1, C // reduction_ratio) # Ensure reduction is at least 1
        
        # FC1: Reduce dimensionality (C -> C/r)
        self.fc1 = nn.Linear(C, reduced_channels)
        
        # FC2: Restore dimensionality (C/r -> C)
        self.fc2 = nn.Linear(reduced_channels, C)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        
        # 1. Main Path: Conv1 -> Norm -> ReLU
        # x_conv1 is the point where the path splits for attention
        x_conv1 = self.relu(self.norm1(self.conv1(x)))
        
        # 2. Main Path: Conv2 -> Norm
        x_conv2 = self.norm2(self.conv2(x_conv1))
        
        # 3. SE Attention Path (Squeeze and Excitation)
        # Squeeze: GlobalPool on x_conv1. Output: (B, C, 1, 1)
        attention = self.global_pool(x_conv1)
        attention = attention.view(attention.size(0), -1) # Flatten to (B, C)

        # Excitation: FC1 -> ReLU -> FC2 -> Sigmoid. Output: (B, C)
        attention = self.relu(self.fc1(attention))
        attention = self.sigmoid(self.fc2(attention))

        # 4. Rescale and Apply (Multiplication)
        # Reshape attention vector to (B, C, 1, 1) for broadcasting across H and W
        attention = attention.view(x_conv2.size(0), x_conv2.size(1), 1, 1)
        
        # Scaled Conv2 Output: element-wise multiplication
        x_scaled = x_conv2 * attention 

        # 5. Skip Connection and Final ReLU
        # Output = Input + Scaled Conv2 Output
        output = self.relu(x + x_scaled) 
        
        return output


class ResidualStack(nn.Module):
    """Stacks a specified number of ResidualBlock instances."""
    def __init__(self, channels, num_residual_layers, reduction_ratio=16):
        super().__init__()
        # Ensure the ResidualBlock class with attention is accessible
        self.layers = nn.ModuleList([
            ResidualBlock(channels, reduction_ratio)
            for _ in range(num_residual_layers)
        ])

    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %%
class TransposeConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=4, stride=2, padding=1):
        super().__init__()
        self.trans_conv = nn.ConvTranspose2d(
            in_channels,
            out_channels,
            kernel_size=kernel_size,
            stride=stride,
            padding=padding
        )
        
        # Using InstanceNorm2d
        if out_channels > 1:
            self.norm = nn.InstanceNorm2d(out_channels, affine=True)
        else:
            self.norm = nn.Identity() 

        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.trans_conv(x).contiguous() # Ensure contiguity after transpose conv
        return self.relu(self.norm(x))

# %%
class VectorQuantization(nn.Module):
    """
    The Vector Quantization layer.
    Quantizes the input feature map (B, C, H, W) to the nearest codebook vector.
    """
    def __init__(self, num_embeddings, embedding_dim, input_channels, commitment_cost):
        super().__init__()
        self.num_embeddings = num_embeddings # K: Size of the codebook
        self.embedding_dim = embedding_dim   # D: Dimension of each vector
        self.commitment_cost = commitment_cost

        # Define the codebook (the embedding matrix)
        self.embedding = nn.Embedding(self.num_embeddings, self.embedding_dim)
        # Initialize the codebook weights uniformly
        self.embedding.weight.data.uniform_(-1.0 / self.num_embeddings, 1.0 / self.num_embeddings)

    def forward(self, z):
        # 1. Reshape Input: (B, C, H, W) -> (B*H*W, C)
        flat_input = z.permute(0, 2, 3, 1).contiguous() # (B, H, W, C)
        flat_input = flat_input.view(-1, self.embedding_dim) # (N, D) where N=B*H*W

        # 2. Compute Distances: ||z - e_i||^2
        # (N, D) - (K, D) -> (N, K) distance matrix
        distances = (torch.sum(flat_input**2, dim=1, keepdim=True)
                     + torch.sum(self.embedding.weight**2, dim=1)
                     - 2 * torch.matmul(flat_input, self.embedding.weight.t()))

        # 3. Find Nearest Codebook Vector (Min Distance Index)
        # min_encoding_indices is (N,) containing indices 0 to K-1
        min_encoding_indices = torch.argmin(distances, dim=1)
        
        # 4. Quantize: Look up the codebook vector for each index
        # quantized is (N, D)
        quantized = self.embedding(min_encoding_indices).view(z.shape[0], z.shape[2], z.shape[3], -1)
        quantized = quantized.permute(0, 3, 1, 2).contiguous() # (B, C, H, W)

        # 5. Straight-Through Estimator (STE)
        # Gradients of the embedding e_i are copied to the input z_e (encoder output)
        quantized_st = z + (quantized - z).detach()
        
        # 6. Calculate VQ Loss
        # VQ Loss = Codebook loss + Commitment loss
        # Codebook loss (e_i moves towards z_e): ||sg[z_e] - e||^2
        codebook_loss = F.mse_loss(quantized, z.detach())
        # Commitment loss (z_e commits to e_i): ||z_e - sg[e]||^2
        commitment_loss = F.mse_loss(z, quantized.detach()) * self.commitment_cost
        
        vq_loss = codebook_loss + commitment_loss
        
        return quantized_st, vq_loss, min_encoding_indices

# %%
class VQVCAE(nn.Module):
    def __init__(self, input_channels, num_hiddens, num_residual_layers, 
                 num_embeddings_bottom, embedding_dim_bottom, 
                 num_embeddings_top, embedding_dim_top, 
                 commitment_cost=0.25):
        
        super().__init__()
        
        self.C = num_hiddens
        
        # --- ENCODER PATH (Bottom -> Top) ---
        
        # Initial Downsampling (128 -> 32)
        # Conv1 (128 -> 64) and Conv2 (64 -> 32) and Conv3 (32 -> 16)
        self.enc_conv1 = nn.Conv2d(input_channels, self.C, kernel_size=4, stride=2, padding=1)
        self.enc_conv2 = nn.Conv2d(self.C, self.C, kernel_size=4, stride=2, padding=1)
        
        # Residual Block Stack 1 (RB 2 in diagram)
        self.res_stack1 = ResidualStack(self.C, num_residual_layers)
        
        # VQ Module 1 (Bottom Latent, operates at 32x32)
        self.vq_module1 = VectorQuantization(num_embeddings_bottom, embedding_dim_bottom, self.C, commitment_cost)
        
        # Downsampling for Top Latent (32 -> 8)
        # Conv4 (32 -> 16) and Conv5 (16 -> 8)
        self.enc_conv4 = nn.Conv2d(self.C, self.C, kernel_size=4, stride=2, padding=1)
        self.enc_conv5 = nn.Conv2d(self.C, self.C, kernel_size=4, stride=2, padding=1)
        
        # Residual Block Stack 2 (RB 2 in diagram)
        self.res_stack2 = ResidualStack(self.C, num_residual_layers)
        
        # VQ Module 2 (Top Latent, operates at 8x8)
        self.vq_module2 = VectorQuantization(num_embeddings_top, embedding_dim_top, self.C, commitment_cost)

        # Bottleneck Conv (Conv7 in diagram)
        self.bottleneck_conv = nn.Conv2d(self.C, self.C, kernel_size=3, stride=1, padding=1)
        
        # --- DECODER PATH (Top -> Bottom) ---
        
        # Decoder Top Path (Upsamples Z_q2: 8 -> 32)
        # TransConv1 (Upsamples 8 -> 16)
        self.dec_transconv1 = nn.ConvTranspose2d(self.C, self.C, kernel_size=4, stride=2, padding=1) 
        self.dec_conv8 = nn.Conv2d(self.C, self.C, kernel_size=3, stride=1, padding=1) # Conv8
        self.dec_res_stack3 = ResidualStack(self.C, num_residual_layers) # RB 2
        
        # TransConv2 (Upsamples 16 -> 32)
        # This output will be concatenated with Z_q1 (the bottom latent)
        self.dec_transconv2 = nn.ConvTranspose2d(self.C, self.C, kernel_size=4, stride=2, padding=1) 
        
        # Skip Connection / Merging Conv (Conv9 in diagram)
        # Concatenates: [Upsampled Z_q2 (C) + Z_q1 (C)] -> 2*C channels, then Conv9 reduces to C
        self.dec_conv9 = nn.Conv2d(2 * self.C, self.C, kernel_size=3, stride=1, padding=1)
        
        # Decoder Bottom Path (32 -> 128)
        # TransConv10 (Upsamples 32 -> 64)
        self.dec_transconv10 = nn.ConvTranspose2d(self.C, self.C, kernel_size=4, stride=2, padding=1) 
        self.dec_res_stack4 = ResidualStack(self.C, num_residual_layers) # RB 2
        
        # Final Conv (Conv3) (Upsamples 64 -> 128)
        self.dec_conv3 = nn.ConvTranspose2d(self.C, input_channels, kernel_size=4, stride=2, padding=1)
        
        
    def forward(self, x):
        
        # --- 1. ENCODER ---
        
        # Bottom Path (128 -> 32)
        x = F.relu(self.enc_conv1(x))
        x = F.relu(self.enc_conv2(x))
        x_e1 = self.res_stack1(x) # Z_e1
        
        # VQ 1 (Bottom Latent, Z_q1)
        z_q1, diff1, _ = self.vq_module1(x_e1)
        
        # Top Path (32 -> 8)
        x = F.relu(self.enc_conv4(z_q1)) # Use quantized latent for next stage
        x = F.relu(self.enc_conv5(x))
        x_e2 = self.res_stack2(x) # Z_e2
        
        # VQ 2 (Top Latent, Z_q2)
        z_q2, diff2, _ = self.vq_module2(x_e2)
        
        # Bottleneck Conv (Conv7)
        z_q2 = F.relu(self.bottleneck_conv(z_q2))
        
        # --- 2. DECODER ---
        
        # Decoder Top Path (8 -> 32)
        x_d = F.relu(self.dec_transconv1(z_q2)) # 8 -> 16 (TransConv1)
        x_d = F.relu(self.dec_conv8(x_d))
        x_d = self.dec_res_stack3(x_d) 
        
        x_d = F.relu(self.dec_transconv2(x_d)) # 16 -> 32 (TransConv2)
        
        # Feature Map Concatenation (Skip Connection)
        x_concat = torch.cat([x_d, z_q1], dim=1) # Concatenate with Bottom Latent
        
        # Conv9 (Merge and Process)
        x_d = F.relu(self.dec_conv9(x_concat))
        
        # Decoder Bottom Path (32 -> 128)
        x_d = F.relu(self.dec_transconv10(x_d)) # 32 -> 64 (TransConv10)
        x_d = self.dec_res_stack4(x_d)
        
        # Final Conv (Conv3)
        x_recon = self.dec_conv3(x_d) # 64 -> 128
        
        # Total VQ Loss
        total_vq_loss = diff1 + diff2
        
        return x_recon, total_vq_loss, (z_q1, z_q2)

# %%
# Model Hyperparameters
input_channels = 1      # RGB images
num_hiddens = 128       # Feature map size (D) - Divisible by 8 (NUM_GROUPS)
num_residual_layers = 2
num_embeddings = 512
embedding_dim = 64      # Dimension of codebook vectors

# --- 0. Updated Hyperparameters ---
BATCH_SIZE = 128
NUM_EPOCHS = 100 
INPUT_CHANNELS = 1 
NUM_HIDDENS = 128            # C (The number of channels used throughout)
NUM_RESIDUAL_LAYERS = 2    # The number of RBs in each ResidualStack
LEARNING_RATE = 1e-3

# NEW: Dual VQ Hyperparameters
# VQ1 (Bottom Latent, 32x32 resolution)
NUM_EMBEDDINGS_BOTTOM = 512
EMBEDDING_DIM_BOTTOM = 64
# VQ2 (Top Latent, 8x8 resolution)
NUM_EMBEDDINGS_TOP = 512
EMBEDDING_DIM_TOP = 64
COMMITMENT_COST = 0.25

# Create model instance
model = VQVCAE(
    input_channels=INPUT_CHANNELS, 
    num_hiddens=NUM_HIDDENS, 
    num_residual_layers=NUM_RESIDUAL_LAYERS, 
    
    num_embeddings_bottom=NUM_EMBEDDINGS_BOTTOM, 
    embedding_dim_bottom=EMBEDDING_DIM_BOTTOM, 
    
    num_embeddings_top=NUM_EMBEDDINGS_TOP, 
    embedding_dim_top=EMBEDDING_DIM_TOP,
    
    commitment_cost=COMMITMENT_COST
)

# Dummy Input (Batch size, channels, Height, Width)
dummy_input = torch.randn(BATCH_SIZE, 1, 128, 128)

# Run forward pass (This will now run without GroupNorm errors)
output, vq_loss, indices = model(dummy_input)

print(f"Input shape: {dummy_input.shape}")
print(f"Reconstructed shape: {output.shape}")
print(f"VQ Loss: {vq_loss.item():.4f}")
# Out:
# Input shape: torch.Size([128, 1, 128, 128])
# Reconstructed shape: torch.Size([128, 1, 128, 128])
# VQ Loss: 0.8817

# %%
class TopCrop(v2.Transform):
    def __init__(self, top_pixels: int):
        super().__init__()
        self.top_pixels = top_pixels

    def transform(self, input, params):
        if isinstance(input, Image.Image):
            w, h = input.size
        else:  # assume tensor with shape [C, H, W]
            h, w = input.shape[-2], input.shape[-1]
            
        return v2.functional.crop(input, top=self.top_pixels, left=0,
                                  height=h-self.top_pixels, width=w)

transform = v2.Compose([
    TopCrop(350),
    v2.Resize((128, 128)),
    v2.ColorJitter(contrast=(2.0, 2.0)),
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    # v2.RandomRotation(180),
    # v2.RandomPerspective(),
])

dataset = Kantec2509Dataset(transform=transform)

train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)

batch = next(iter(train_dataloader))
images = batch

fig, axes = plt.subplots(2, 4, figsize=(16, 8))
axes = axes.flatten()
for i, img in enumerate(images[:8]):
    axes[i].imshow(img.permute(1, 2, 0), cmap="gray")
    axes[i].axis("off")

# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim

# # --- Hyperparameters ---
# input_channels = 1      
# num_hiddens = 128       
# num_residual_layers = 2
# num_embeddings = 512
# embedding_dim = 64      
# learning_rate = 1e-3

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# model = VQVCAE(input_channels, num_hiddens, num_residual_layers, num_embeddings, embedding_dim)
model.train()
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=learning_rate, amsgrad=False)
reconstruction_criterion = nn.MSELoss()

# %%
import torch
import os

def save_checkpoint(model, optimizer, epoch, total_loss, filename="vqvcae_checkpoint.pth"):
    """Saves the current training state."""
    
    # Optional: Create the directory if it doesn't exist
    # os.makedirs("checkpoints", exist_ok=True) 
    
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'loss': total_loss,
    }
    # Save the dictionary to a file
    torch.save(checkpoint, filename)
    print(f"Checkpoint saved to {filename} at Epoch {epoch+1}")

# %%
def load_checkpoint(model, optimizer, filename="vqvcae_best_model.pth", device='cpu'):
    """Loads a saved checkpoint and returns the starting epoch."""
    
    if not os.path.exists(filename):
        print(f"Checkpoint file {filename} not found. Starting training from epoch 0.")
        return 0
    
    # Load the checkpoint dictionary, mapping tensors to the correct device
    checkpoint = torch.load(filename, map_location=device)
    
    # Load the state dictionaries
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    
    # Determine the starting epoch
    start_epoch = checkpoint['epoch'] + 1
    
    print(f"Checkpoint loaded successfully. Resuming training from Epoch {start_epoch}.")
    
    return start_epoch

# %%
import torch

def validate_epoch(model, val_dataloader, criterion, device):
    """Calculates the average total loss on the validation set."""
    
    model.eval() # Set model to evaluation mode (crucial!)
    total_val_loss = 0.0
    num_batches = 0
    
    # Disable gradient calculations during validation
    with torch.no_grad():
        for data in val_dataloader:
            data = data.to(device)
            
            x_recon, vq_loss, _ = model(data)
            
            recon_loss = criterion(x_recon, data)
            total_loss = recon_loss + vq_loss
            
            total_val_loss += total_loss.item()
            num_batches += 1
            
    # Calculate average loss over the validation set
    avg_val_loss = total_val_loss / num_batches
    print(f'\n--- Validation Complete --- Avg. Validation Loss: {avg_val_loss:.4f}')
    
    return avg_val_loss

# %%
def train_vqvae_final(model, train_dataloader, val_dataloader, optimizer, num_epochs, criterion, device, start_epoch=0, checkpoint_path="vqvcae_best_model.pth"):
    
    print(f"Starting VQVCAE Training on device: {device}")
    
    # Initialize best_val_loss from a very high number
    best_val_loss = float('inf') 
    
    for epoch in range(start_epoch, start_epoch + num_epochs):
        model.train() # Set to training mode at the start of the epoch
        avg_train_loss = 0.0
        
        for i, data in enumerate(train_dataloader): 
            
            # Training steps (Forward/Backward Pass)
            data = data.to(device)
            x_recon, vq_loss, _ = model(data)
            recon_loss = criterion(x_recon, data)
            total_loss = recon_loss + vq_loss
            
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            avg_train_loss += total_loss.item()
            
            # --- Logging ---
            if (i + 1) % 10 == 0:
                print(f'Epoch [{epoch+1}/{start_epoch + num_epochs}], '
                      f'Step [{i+1}/{len(train_dataloader)}], '
                      f'Total Loss: {total_loss.item():.4f}, '
                      f'Recon Loss: {recon_loss.item():.4f}, '
                      f'VQ Loss: {vq_loss.item():.4f}')
                
        # -------------------------------------------------------------
        # End of Epoch: Run Validation
        # -------------------------------------------------------------
        current_val_loss = validate_epoch(model, val_dataloader, criterion, device)
        
        # Save Checkpoint Logic: Save only if validation loss improves
        if current_val_loss < best_val_loss:
            best_val_loss = current_val_loss
            # Call your separate save_checkpoint function
            save_checkpoint(model, optimizer, epoch, current_val_loss, checkpoint_path)
            print(f"✅ Saved Best Model with Val Loss: {best_val_loss:.4f}")
            
    print("Training finished. 🎉")

# %%
def test_model(model, test_dataloader, criterion, device, checkpoint_path="vqvcae_best_model.pth"):
    """
    Loads the best saved model and evaluates performance on the test set.
    """
    # Load the best model weights first (optional, but highly recommended)
    try:
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        print(f"Loaded best model saved at epoch {checkpoint['epoch']+1}.")
    except Exception as e:
        print(f"Warning: Could not load checkpoint from {checkpoint_path}. Testing current model state.")
    
    model.eval() # Set to evaluation mode
    total_test_loss = 0.0
    num_batches = 0
    
    # Store individual image errors or latent codes if you plan to do anomaly detection
    # all_anomaly_scores = []
    
    with torch.no_grad():
        for data in test_dataloader:
            data = data.to(device)
            
            x_recon, vq_loss, _ = model(data)
            
            recon_loss = criterion(x_recon, data)
            total_loss = recon_loss + vq_loss
            
            total_test_loss += total_loss.item()
            num_batches += 1
            
            # Example: Calculate anomaly scores here if desired (see previous step)
            # anomaly_scores = torch.sum(torch.square(x_recon - data), dim=[1, 2, 3]).cpu().numpy()
            # all_anomaly_scores.extend(anomaly_scores)

    avg_test_loss = total_test_loss / num_batches
    print(f'\n==================================================')
    print(f'FINAL TEST RESULT: Avg. Test Loss: {avg_test_loss:.4f}')
    print(f'==================================================')
    
    return avg_test_loss # , all_anomaly_scores

# %%
# Initialize start_epoch and best_val_loss
start_epoch, best_val_loss = 0, float('inf')

num_epochs = 900

CHECKPOINT_PATH = "vqvcae_best_model.pth"

# Load existing checkpoint if it exists
try:
    start_epoch = load_checkpoint(model, optimizer, CHECKPOINT_PATH, device)
except Exception as e:
    print(f"Error loading checkpoint: {e}. Starting fresh.")
    start_epoch, best_val_loss = 0, float('inf')


# --- 4. EXECUTION: Training and Validation ---
print("\n" + "="*50)
print("STARTING/RESUMING TRAINING")
print("="*50)

# Pass all necessary objects to the training function
train_vqvae_final(
    model=model, 
    train_dataloader=train_dataloader, 
    val_dataloader=val_dataloader,
    optimizer=optimizer, 
    num_epochs=num_epochs, 
    criterion=reconstruction_criterion, 
    device=device, 
    start_epoch=start_epoch,
    checkpoint_path=CHECKPOINT_PATH
)


# --- 5. EXECUTION: Final Testing ---
print("\n" + "="*50)
print("RUNNING FINAL TEST EVALUATION")
print("="*50)

# The test function will load the best model saved during training
final_test_loss = test_model(
    model=model, 
    test_dataloader=test_dataloader, 
    criterion=reconstruction_criterion, 
    device=device,
    checkpoint_path=CHECKPOINT_PATH
)
# Out:
# Checkpoint loaded successfully. Resuming training from Epoch 100.
#
# ==================================================
# STARTING/RESUMING TRAINING
# ==================================================
# Starting VQVCAE Training on device: cuda
# Epoch [101/1000], Step [10/12], Total Loss: 0.0308, Recon Loss: 0.0016, VQ Loss: 0.0292
#
# --- Validation Complete --- Avg. Validation Loss: 0.0307
# Checkpoint saved to vqvcae_best_model.pth at Epoch 101
# ✅ Saved Best Model with Val Loss: 0.0307
# Epoch [102/1000], Step [10/12], Total Loss: 0.0298, Recon Loss: 0.0016, VQ Loss: 0.0283
#
# --- Validation Complete --- Avg. Validation Loss: 0.0296
# Checkpoint saved to vqvcae_best_model.pth at Epoch 102
# ✅ Saved Best Model with Val Loss: 0.0296
# Epoch [103/1000], Step [10/12], Total Loss: 0.0289, Recon Loss: 0.0016, VQ Loss: 0.0273
#
# --- Validation Complete --- Avg. Validation Loss: 0.0286
# Checkpoint saved to vqvcae_best_model.pth at Epoch 103
# ✅ Saved Best Model with Val Loss: 0.0286
# Epoch [104/1000], Step [10/12], Total Loss: 0.0277, Recon Loss: 0.0017, VQ Loss: 0.0260
#
# --- Validation Complete --- Avg. Validation Loss: 0.0279
# Checkpoint saved to vqvcae_best_model.pth at Epoch 104
# ✅ Saved Best Model with Val Loss: 0.0279
# Epoch [105/1000], Step [10/12], Total Loss: 0.0277, Recon Loss: 0.0026, VQ Loss: 0.0252
#
# --- Validation Complete --- Avg. Validation Loss: 0.0267
# Checkpoint saved to vqvcae_best_model.pth at Epoch 105
# ✅ Saved Best Model with Val Loss: 0.0267
# Epoch [106/1000], Step [10/12], Total Loss: 0.0258, Recon Loss: 0.0016, VQ Loss: 0.0242
#
# --- Validation Complete --- Avg. Validation Loss: 0.0257
# Checkpoint saved to vqvcae_best_model.pth at Epoch 106
# ✅ Saved Best Model with Val Loss: 0.0257
# Epoch [107/1000], Step [10/12], Total Loss: 0.0248, Recon Loss: 0.0016, VQ Loss: 0.0232
#
# --- Validation Complete --- Avg. Validation Loss: 0.0247
# Checkpoint saved to vqvcae_best_model.pth at Epoch 107
# ✅ Saved Best Model with Val Loss: 0.0247
# Epoch [108/1000], Step [10/12], Total Loss: 0.0243, Recon Loss: 0.0019, VQ Loss: 0.0224
#
# --- Validation Complete --- Avg. Validation Loss: 0.0241
# Checkpoint saved to vqvcae_best_model.pth at Epoch 108
# ✅ Saved Best Model with Val Loss: 0.0241
# Epoch [109/1000], Step [10/12], Total Loss: 0.0234, Recon Loss: 0.0018, VQ Loss: 0.0216
#
# --- Validation Complete --- Avg. Validation Loss: 0.0233
# Checkpoint saved to vqvcae_best_model.pth at Epoch 109
# ✅ Saved Best Model with Val Loss: 0.0233
# Epoch [110/1000], Step [10/12], Total Loss: 0.0229, Recon Loss: 0.0017, VQ Loss: 0.0212
#
# --- Validation Complete --- Avg. Validation Loss: 0.0225
# Checkpoint saved to vqvcae_best_model.pth at Epoch 110
# ✅ Saved Best Model with Val Loss: 0.0225
# Epoch [111/1000], Step [10/12], Total Loss: 0.0223, Recon Loss: 0.0022, VQ Loss: 0.0202
#
# --- Validation Complete --- Avg. Validation Loss: 0.0224
# Checkpoint saved to vqvcae_best_model.pth at Epoch 111
# ✅ Saved Best Model with Val Loss: 0.0224
# Epoch [112/1000], Step [10/12], Total Loss: 0.0217, Recon Loss: 0.0023, VQ Loss: 0.0195
#
# --- Validation Complete --- Avg. Validation Loss: 0.0216
# Checkpoint saved to vqvcae_best_model.pth at Epoch 112
# ✅ Saved Best Model with Val Loss: 0.0216
# Epoch [113/1000], Step [10/12], Total Loss: 0.0206, Recon Loss: 0.0018, VQ Loss: 0.0188
#
# --- Validation Complete --- Avg. Validation Loss: 0.0205
# Checkpoint saved to vqvcae_best_model.pth at Epoch 113
# ✅ Saved Best Model with Val Loss: 0.0205
# Epoch [114/1000], Step [10/12], Total Loss: 0.0197, Recon Loss: 0.0016, VQ Loss: 0.0180
#
# --- Validation Complete --- Avg. Validation Loss: 0.0193
# Checkpoint saved to vqvcae_best_model.pth at Epoch 114
# ✅ Saved Best Model with Val Loss: 0.0193
# Epoch [115/1000], Step [10/12], Total Loss: 0.0189, Recon Loss: 0.0015, VQ Loss: 0.0175
#
# --- Validation Complete --- Avg. Validation Loss: 0.0188
# Checkpoint saved to vqvcae_best_model.pth at Epoch 115
# ✅ Saved Best Model with Val Loss: 0.0188
# Epoch [116/1000], Step [10/12], Total Loss: 0.0185, Recon Loss: 0.0015, VQ Loss: 0.0170
#
# --- Validation Complete --- Avg. Validation Loss: 0.0183
# Checkpoint saved to vqvcae_best_model.pth at Epoch 116
# ✅ Saved Best Model with Val Loss: 0.0183
# Epoch [117/1000], Step [10/12], Total Loss: 0.0180, Recon Loss: 0.0015, VQ Loss: 0.0165
#
# --- Validation Complete --- Avg. Validation Loss: 0.0179
# Checkpoint saved to vqvcae_best_model.pth at Epoch 117
# ✅ Saved Best Model with Val Loss: 0.0179
# Epoch [118/1000], Step [10/12], Total Loss: 0.0183, Recon Loss: 0.0023, VQ Loss: 0.0161
#
# --- Validation Complete --- Avg. Validation Loss: 0.0195
# Epoch [119/1000], Step [10/12], Total Loss: 0.0184, Recon Loss: 0.0028, VQ Loss: 0.0156
#
# --- Validation Complete --- Avg. Validation Loss: 0.0185
# Epoch [120/1000], Step [10/12], Total Loss: 0.0172, Recon Loss: 0.0019, VQ Loss: 0.0153
#
# --- Validation Complete --- Avg. Validation Loss: 0.0170
# Checkpoint saved to vqvcae_best_model.pth at Epoch 120
# ✅ Saved Best Model with Val Loss: 0.0170
# Epoch [121/1000], Step [10/12], Total Loss: 0.0165, Recon Loss: 0.0016, VQ Loss: 0.0149
#
# --- Validation Complete --- Avg. Validation Loss: 0.0164
# Checkpoint saved to vqvcae_best_model.pth at Epoch 121
# ✅ Saved Best Model with Val Loss: 0.0164
# Epoch [122/1000], Step [10/12], Total Loss: 0.0160, Recon Loss: 0.0015, VQ Loss: 0.0145
#
# --- Validation Complete --- Avg. Validation Loss: 0.0160
# Checkpoint saved to vqvcae_best_model.pth at Epoch 122
# ✅ Saved Best Model with Val Loss: 0.0160
# Epoch [123/1000], Step [10/12], Total Loss: 0.0157, Recon Loss: 0.0014, VQ Loss: 0.0143
#
# --- Validation Complete --- Avg. Validation Loss: 0.0157
# Checkpoint saved to vqvcae_best_model.pth at Epoch 123
# ✅ Saved Best Model with Val Loss: 0.0157
# Epoch [124/1000], Step [10/12], Total Loss: 0.0153, Recon Loss: 0.0014, VQ Loss: 0.0139
#
# --- Validation Complete --- Avg. Validation Loss: 0.0153
# Checkpoint saved to vqvcae_best_model.pth at Epoch 124
# ✅ Saved Best Model with Val Loss: 0.0153
# Epoch [125/1000], Step [10/12], Total Loss: 0.0151, Recon Loss: 0.0014, VQ Loss: 0.0137
#
# --- Validation Complete --- Avg. Validation Loss: 0.0151
# Checkpoint saved to vqvcae_best_model.pth at Epoch 125
# ✅ Saved Best Model with Val Loss: 0.0151
# Epoch [126/1000], Step [10/12], Total Loss: 0.0150, Recon Loss: 0.0015, VQ Loss: 0.0135
#
# --- Validation Complete --- Avg. Validation Loss: 0.0150
# Checkpoint saved to vqvcae_best_model.pth at Epoch 126
# ✅ Saved Best Model with Val Loss: 0.0150
# Epoch [127/1000], Step [10/12], Total Loss: 0.0149, Recon Loss: 0.0016, VQ Loss: 0.0133
#
# --- Validation Complete --- Avg. Validation Loss: 0.0149
# Checkpoint saved to vqvcae_best_model.pth at Epoch 127
# ✅ Saved Best Model with Val Loss: 0.0149
# Epoch [128/1000], Step [10/12], Total Loss: 0.0150, Recon Loss: 0.0020, VQ Loss: 0.0130
#
# --- Validation Complete --- Avg. Validation Loss: 0.0153
# Epoch [129/1000], Step [10/12], Total Loss: 0.0144, Recon Loss: 0.0017, VQ Loss: 0.0127
#
# --- Validation Complete --- Avg. Validation Loss: 0.0145
# Checkpoint saved to vqvcae_best_model.pth at Epoch 129
# ✅ Saved Best Model with Val Loss: 0.0145
# Epoch [130/1000], Step [10/12], Total Loss: 0.0143, Recon Loss: 0.0019, VQ Loss: 0.0124
#
# --- Validation Complete --- Avg. Validation Loss: 0.0143
# Checkpoint saved to vqvcae_best_model.pth at Epoch 130
# ✅ Saved Best Model with Val Loss: 0.0143
# Epoch [131/1000], Step [10/12], Total Loss: 0.0137, Recon Loss: 0.0014, VQ Loss: 0.0123
#
# --- Validation Complete --- Avg. Validation Loss: 0.0136
# Checkpoint saved to vqvcae_best_model.pth at Epoch 131
# ✅ Saved Best Model with Val Loss: 0.0136
# Epoch [132/1000], Step [10/12], Total Loss: 0.0135, Recon Loss: 0.0014, VQ Loss: 0.0122
#
# --- Validation Complete --- Avg. Validation Loss: 0.0134
# Checkpoint saved to vqvcae_best_model.pth at Epoch 132
# ✅ Saved Best Model with Val Loss: 0.0134
# Epoch [133/1000], Step [10/12], Total Loss: 0.0135, Recon Loss: 0.0015, VQ Loss: 0.0119
#
# --- Validation Complete --- Avg. Validation Loss: 0.0136
# Epoch [134/1000], Step [10/12], Total Loss: 0.0132, Recon Loss: 0.0016, VQ Loss: 0.0117
#
# --- Validation Complete --- Avg. Validation Loss: 0.0133
# Checkpoint saved to vqvcae_best_model.pth at Epoch 134
# ✅ Saved Best Model with Val Loss: 0.0133
# Epoch [135/1000], Step [10/12], Total Loss: 0.0132, Recon Loss: 0.0018, VQ Loss: 0.0114
#
# --- Validation Complete --- Avg. Validation Loss: 0.0132
# Checkpoint saved to vqvcae_best_model.pth at Epoch 135
# ✅ Saved Best Model with Val Loss: 0.0132
# Epoch [136/1000], Step [10/12], Total Loss: 0.0152, Recon Loss: 0.0040, VQ Loss: 0.0112
#
# --- Validation Complete --- Avg. Validation Loss: 0.0155
# Epoch [137/1000], Step [10/12], Total Loss: 0.0130, Recon Loss: 0.0019, VQ Loss: 0.0110
#
# --- Validation Complete --- Avg. Validation Loss: 0.0126
# Checkpoint saved to vqvcae_best_model.pth at Epoch 137
# ✅ Saved Best Model with Val Loss: 0.0126
# Epoch [138/1000], Step [10/12], Total Loss: 0.0123, Recon Loss: 0.0015, VQ Loss: 0.0109
#
# --- Validation Complete --- Avg. Validation Loss: 0.0124
# Checkpoint saved to vqvcae_best_model.pth at Epoch 138
# ✅ Saved Best Model with Val Loss: 0.0124
# Epoch [139/1000], Step [10/12], Total Loss: 0.0121, Recon Loss: 0.0014, VQ Loss: 0.0107
#
# --- Validation Complete --- Avg. Validation Loss: 0.0120
# Checkpoint saved to vqvcae_best_model.pth at Epoch 139
# ✅ Saved Best Model with Val Loss: 0.0120
# Epoch [140/1000], Step [10/12], Total Loss: 0.0119, Recon Loss: 0.0014, VQ Loss: 0.0105
#
# --- Validation Complete --- Avg. Validation Loss: 0.0118
# Checkpoint saved to vqvcae_best_model.pth at Epoch 140
# ✅ Saved Best Model with Val Loss: 0.0118
# Epoch [141/1000], Step [10/12], Total Loss: 0.0119, Recon Loss: 0.0014, VQ Loss: 0.0105
#
# --- Validation Complete --- Avg. Validation Loss: 0.0117
# Checkpoint saved to vqvcae_best_model.pth at Epoch 141
# ✅ Saved Best Model with Val Loss: 0.0117
# Epoch [142/1000], Step [10/12], Total Loss: 0.0117, Recon Loss: 0.0014, VQ Loss: 0.0103
#
# --- Validation Complete --- Avg. Validation Loss: 0.0117
# Checkpoint saved to vqvcae_best_model.pth at Epoch 142
# ✅ Saved Best Model with Val Loss: 0.0117
# Epoch [143/1000], Step [10/12], Total Loss: 0.0116, Recon Loss: 0.0015, VQ Loss: 0.0101
#
# --- Validation Complete --- Avg. Validation Loss: 0.0116
# Checkpoint saved to vqvcae_best_model.pth at Epoch 143
# ✅ Saved Best Model with Val Loss: 0.0116
# Epoch [144/1000], Step [10/12], Total Loss: 0.0121, Recon Loss: 0.0023, VQ Loss: 0.0098
#
# --- Validation Complete --- Avg. Validation Loss: 0.0119
# Epoch [145/1000], Step [10/12], Total Loss: 0.0114, Recon Loss: 0.0016, VQ Loss: 0.0098
#
# --- Validation Complete --- Avg. Validation Loss: 0.0112
# Checkpoint saved to vqvcae_best_model.pth at Epoch 145
# ✅ Saved Best Model with Val Loss: 0.0112
# Epoch [146/1000], Step [10/12], Total Loss: 0.0109, Recon Loss: 0.0014, VQ Loss: 0.0095
#
# --- Validation Complete --- Avg. Validation Loss: 0.0110
# Checkpoint saved to vqvcae_best_model.pth at Epoch 146
# ✅ Saved Best Model with Val Loss: 0.0110
# Epoch [147/1000], Step [10/12], Total Loss: 0.0109, Recon Loss: 0.0015, VQ Loss: 0.0094
#
# --- Validation Complete --- Avg. Validation Loss: 0.0108
# Checkpoint saved to vqvcae_best_model.pth at Epoch 147
# ✅ Saved Best Model with Val Loss: 0.0108
# Epoch [148/1000], Step [10/12], Total Loss: 0.0107, Recon Loss: 0.0014, VQ Loss: 0.0094
#
# --- Validation Complete --- Avg. Validation Loss: 0.0106
# Checkpoint saved to vqvcae_best_model.pth at Epoch 148
# ✅ Saved Best Model with Val Loss: 0.0106
# Epoch [149/1000], Step [10/12], Total Loss: 0.0106, Recon Loss: 0.0015, VQ Loss: 0.0091
#
# --- Validation Complete --- Avg. Validation Loss: 0.0106
# Checkpoint saved to vqvcae_best_model.pth at Epoch 149
# ✅ Saved Best Model with Val Loss: 0.0106
# Epoch [150/1000], Step [10/12], Total Loss: 0.0111, Recon Loss: 0.0021, VQ Loss: 0.0090
#
# --- Validation Complete --- Avg. Validation Loss: 0.0120
# Epoch [151/1000], Step [10/12], Total Loss: 0.0108, Recon Loss: 0.0019, VQ Loss: 0.0089
#
# --- Validation Complete --- Avg. Validation Loss: 0.0108
# Epoch [152/1000], Step [10/12], Total Loss: 0.0103, Recon Loss: 0.0015, VQ Loss: 0.0088
#
# --- Validation Complete --- Avg. Validation Loss: 0.0102
# Checkpoint saved to vqvcae_best_model.pth at Epoch 152
# ✅ Saved Best Model with Val Loss: 0.0102
# Epoch [153/1000], Step [10/12], Total Loss: 0.0099, Recon Loss: 0.0014, VQ Loss: 0.0086
#
# --- Validation Complete --- Avg. Validation Loss: 0.0100
# Checkpoint saved to vqvcae_best_model.pth at Epoch 153
# ✅ Saved Best Model with Val Loss: 0.0100
# Epoch [154/1000], Step [10/12], Total Loss: 0.0098, Recon Loss: 0.0014, VQ Loss: 0.0085
#
# --- Validation Complete --- Avg. Validation Loss: 0.0097
# Checkpoint saved to vqvcae_best_model.pth at Epoch 154
# ✅ Saved Best Model with Val Loss: 0.0097
# Epoch [155/1000], Step [10/12], Total Loss: 0.0098, Recon Loss: 0.0016, VQ Loss: 0.0083
#
# --- Validation Complete --- Avg. Validation Loss: 0.0098
# Epoch [156/1000], Step [10/12], Total Loss: 0.0102, Recon Loss: 0.0019, VQ Loss: 0.0082
#
# --- Validation Complete --- Avg. Validation Loss: 0.0107
# Epoch [157/1000], Step [10/12], Total Loss: 0.0105, Recon Loss: 0.0024, VQ Loss: 0.0081
#
# --- Validation Complete --- Avg. Validation Loss: 0.0099
# Epoch [158/1000], Step [10/12], Total Loss: 0.0095, Recon Loss: 0.0015, VQ Loss: 0.0080
#
# --- Validation Complete --- Avg. Validation Loss: 0.0094
# Checkpoint saved to vqvcae_best_model.pth at Epoch 158
# ✅ Saved Best Model with Val Loss: 0.0094
# Epoch [159/1000], Step [10/12], Total Loss: 0.0093, Recon Loss: 0.0014, VQ Loss: 0.0079
#
# --- Validation Complete --- Avg. Validation Loss: 0.0092
# Checkpoint saved to vqvcae_best_model.pth at Epoch 159
# ✅ Saved Best Model with Val Loss: 0.0092
# Epoch [160/1000], Step [10/12], Total Loss: 0.0090, Recon Loss: 0.0013, VQ Loss: 0.0077
#
# --- Validation Complete --- Avg. Validation Loss: 0.0091
# Checkpoint saved to vqvcae_best_model.pth at Epoch 160
# ✅ Saved Best Model with Val Loss: 0.0091
# Epoch [161/1000], Step [10/12], Total Loss: 0.0089, Recon Loss: 0.0013, VQ Loss: 0.0076
#
# --- Validation Complete --- Avg. Validation Loss: 0.0089
# Checkpoint saved to vqvcae_best_model.pth at Epoch 161
# ✅ Saved Best Model with Val Loss: 0.0089
# Epoch [162/1000], Step [10/12], Total Loss: 0.0089, Recon Loss: 0.0014, VQ Loss: 0.0075
#
# --- Validation Complete --- Avg. Validation Loss: 0.0092
# Epoch [163/1000], Step [10/12], Total Loss: 0.0094, Recon Loss: 0.0020, VQ Loss: 0.0074
#
# --- Validation Complete --- Avg. Validation Loss: 0.0090
# Epoch [164/1000], Step [10/12], Total Loss: 0.0090, Recon Loss: 0.0016, VQ Loss: 0.0073
#
# --- Validation Complete --- Avg. Validation Loss: 0.0086
# Checkpoint saved to vqvcae_best_model.pth at Epoch 164
# ✅ Saved Best Model with Val Loss: 0.0086
# Epoch [165/1000], Step [10/12], Total Loss: 0.0088, Recon Loss: 0.0014, VQ Loss: 0.0074
#
# --- Validation Complete --- Avg. Validation Loss: 0.0086
# Checkpoint saved to vqvcae_best_model.pth at Epoch 165
# ✅ Saved Best Model with Val Loss: 0.0086
# Epoch [166/1000], Step [10/12], Total Loss: 0.0087, Recon Loss: 0.0016, VQ Loss: 0.0071
#
# --- Validation Complete --- Avg. Validation Loss: 0.0087
# Epoch [167/1000], Step [10/12], Total Loss: 0.0090, Recon Loss: 0.0019, VQ Loss: 0.0071
#
# --- Validation Complete --- Avg. Validation Loss: 0.0093
# Epoch [168/1000], Step [10/12], Total Loss: 0.0086, Recon Loss: 0.0016, VQ Loss: 0.0070
#
# --- Validation Complete --- Avg. Validation Loss: 0.0083
# Checkpoint saved to vqvcae_best_model.pth at Epoch 168
# ✅ Saved Best Model with Val Loss: 0.0083
# Epoch [169/1000], Step [10/12], Total Loss: 0.0082, Recon Loss: 0.0013, VQ Loss: 0.0069
#
# --- Validation Complete --- Avg. Validation Loss: 0.0083
# Epoch [170/1000], Step [10/12], Total Loss: 0.0083, Recon Loss: 0.0015, VQ Loss: 0.0068
#
# --- Validation Complete --- Avg. Validation Loss: 0.0082
# Checkpoint saved to vqvcae_best_model.pth at Epoch 170
# ✅ Saved Best Model with Val Loss: 0.0082
# Epoch [171/1000], Step [10/12], Total Loss: 0.0081, Recon Loss: 0.0013, VQ Loss: 0.0067
#
# --- Validation Complete --- Avg. Validation Loss: 0.0081
# Checkpoint saved to vqvcae_best_model.pth at Epoch 171
# ✅ Saved Best Model with Val Loss: 0.0081
# Epoch [172/1000], Step [10/12], Total Loss: 0.0082, Recon Loss: 0.0015, VQ Loss: 0.0067
#
# --- Validation Complete --- Avg. Validation Loss: 0.0086
# Epoch [173/1000], Step [10/12], Total Loss: 0.0093, Recon Loss: 0.0027, VQ Loss: 0.0066
#
# --- Validation Complete --- Avg. Validation Loss: 0.0104
# Epoch [174/1000], Step [10/12], Total Loss: 0.0085, Recon Loss: 0.0019, VQ Loss: 0.0066
#
# --- Validation Complete --- Avg. Validation Loss: 0.0085
# Epoch [175/1000], Step [10/12], Total Loss: 0.0079, Recon Loss: 0.0013, VQ Loss: 0.0066
#
# --- Validation Complete --- Avg. Validation Loss: 0.0079
# Checkpoint saved to vqvcae_best_model.pth at Epoch 175
# ✅ Saved Best Model with Val Loss: 0.0079
# Epoch [176/1000], Step [10/12], Total Loss: 0.0077, Recon Loss: 0.0013, VQ Loss: 0.0064
#
# --- Validation Complete --- Avg. Validation Loss: 0.0077
# Checkpoint saved to vqvcae_best_model.pth at Epoch 176
# ✅ Saved Best Model with Val Loss: 0.0077
# Epoch [177/1000], Step [10/12], Total Loss: 0.0074, Recon Loss: 0.0012, VQ Loss: 0.0062
#
# --- Validation Complete --- Avg. Validation Loss: 0.0075
# Checkpoint saved to vqvcae_best_model.pth at Epoch 177
# ✅ Saved Best Model with Val Loss: 0.0075
# Epoch [178/1000], Step [10/12], Total Loss: 0.0074, Recon Loss: 0.0013, VQ Loss: 0.0062
#
# --- Validation Complete --- Avg. Validation Loss: 0.0074
# Checkpoint saved to vqvcae_best_model.pth at Epoch 178
# ✅ Saved Best Model with Val Loss: 0.0074
# Epoch [179/1000], Step [10/12], Total Loss: 0.0076, Recon Loss: 0.0015, VQ Loss: 0.0061
#
# --- Validation Complete --- Avg. Validation Loss: 0.0078
# Epoch [180/1000], Step [10/12], Total Loss: 0.0076, Recon Loss: 0.0016, VQ Loss: 0.0060
#
# --- Validation Complete --- Avg. Validation Loss: 0.0073
# Checkpoint saved to vqvcae_best_model.pth at Epoch 180
# ✅ Saved Best Model with Val Loss: 0.0073
# Epoch [181/1000], Step [10/12], Total Loss: 0.0074, Recon Loss: 0.0013, VQ Loss: 0.0060
#
# --- Validation Complete --- Avg. Validation Loss: 0.0073
# Checkpoint saved to vqvcae_best_model.pth at Epoch 181
# ✅ Saved Best Model with Val Loss: 0.0073
# Epoch [182/1000], Step [10/12], Total Loss: 0.0071, Recon Loss: 0.0013, VQ Loss: 0.0059
#
# --- Validation Complete --- Avg. Validation Loss: 0.0071
# Checkpoint saved to vqvcae_best_model.pth at Epoch 182
# ✅ Saved Best Model with Val Loss: 0.0071
# Epoch [183/1000], Step [10/12], Total Loss: 0.0071, Recon Loss: 0.0012, VQ Loss: 0.0058
#
# --- Validation Complete --- Avg. Validation Loss: 0.0071
# Checkpoint saved to vqvcae_best_model.pth at Epoch 183
# ✅ Saved Best Model with Val Loss: 0.0071
# Epoch [184/1000], Step [10/12], Total Loss: 0.0071, Recon Loss: 0.0013, VQ Loss: 0.0058
#
# --- Validation Complete --- Avg. Validation Loss: 0.0071
# Epoch [185/1000], Step [10/12], Total Loss: 0.0079, Recon Loss: 0.0023, VQ Loss: 0.0056
#
# --- Validation Complete --- Avg. Validation Loss: 0.0081
# Epoch [186/1000], Step [10/12], Total Loss: 0.0075, Recon Loss: 0.0018, VQ Loss: 0.0057
#
# --- Validation Complete --- Avg. Validation Loss: 0.0071
# Epoch [187/1000], Step [10/12], Total Loss: 0.0069, Recon Loss: 0.0014, VQ Loss: 0.0055
#
# --- Validation Complete --- Avg. Validation Loss: 0.0069
# Checkpoint saved to vqvcae_best_model.pth at Epoch 187
# ✅ Saved Best Model with Val Loss: 0.0069
# Epoch [188/1000], Step [10/12], Total Loss: 0.0068, Recon Loss: 0.0013, VQ Loss: 0.0055
#
# --- Validation Complete --- Avg. Validation Loss: 0.0067
# Checkpoint saved to vqvcae_best_model.pth at Epoch 188
# ✅ Saved Best Model with Val Loss: 0.0067
# Epoch [189/1000], Step [10/12], Total Loss: 0.0068, Recon Loss: 0.0013, VQ Loss: 0.0055
#
# --- Validation Complete --- Avg. Validation Loss: 0.0067
# Checkpoint saved to vqvcae_best_model.pth at Epoch 189
# ✅ Saved Best Model with Val Loss: 0.0067
# Epoch [190/1000], Step [10/12], Total Loss: 0.0067, Recon Loss: 0.0013, VQ Loss: 0.0055
#
# --- Validation Complete --- Avg. Validation Loss: 0.0066
# Checkpoint saved to vqvcae_best_model.pth at Epoch 190
# ✅ Saved Best Model with Val Loss: 0.0066
# Epoch [191/1000], Step [10/12], Total Loss: 0.0067, Recon Loss: 0.0014, VQ Loss: 0.0053
#
# --- Validation Complete --- Avg. Validation Loss: 0.0068
# Epoch [192/1000], Step [10/12], Total Loss: 0.0085, Recon Loss: 0.0032, VQ Loss: 0.0052
#
# --- Validation Complete --- Avg. Validation Loss: 0.0091
# Epoch [193/1000], Step [10/12], Total Loss: 0.0074, Recon Loss: 0.0021, VQ Loss: 0.0053
#
# --- Validation Complete --- Avg. Validation Loss: 0.0070
# Epoch [194/1000], Step [10/12], Total Loss: 0.0067, Recon Loss: 0.0015, VQ Loss: 0.0052
#
# --- Validation Complete --- Avg. Validation Loss: 0.0065
# Checkpoint saved to vqvcae_best_model.pth at Epoch 194
# ✅ Saved Best Model with Val Loss: 0.0065
# Epoch [195/1000], Step [10/12], Total Loss: 0.0063, Recon Loss: 0.0013, VQ Loss: 0.0051
#
# --- Validation Complete --- Avg. Validation Loss: 0.0063
# Checkpoint saved to vqvcae_best_model.pth at Epoch 195
# ✅ Saved Best Model with Val Loss: 0.0063
# Epoch [196/1000], Step [10/12], Total Loss: 0.0064, Recon Loss: 0.0014, VQ Loss: 0.0050
#
# --- Validation Complete --- Avg. Validation Loss: 0.0065
# Epoch [197/1000], Step [10/12], Total Loss: 0.0064, Recon Loss: 0.0013, VQ Loss: 0.0052
#
# --- Validation Complete --- Avg. Validation Loss: 0.0062
# Checkpoint saved to vqvcae_best_model.pth at Epoch 197
# ✅ Saved Best Model with Val Loss: 0.0062
# Epoch [198/1000], Step [10/12], Total Loss: 0.0062, Recon Loss: 0.0012, VQ Loss: 0.0050
#
# --- Validation Complete --- Avg. Validation Loss: 0.0061
# Checkpoint saved to vqvcae_best_model.pth at Epoch 198
# ✅ Saved Best Model with Val Loss: 0.0061
# Epoch [199/1000], Step [10/12], Total Loss: 0.0062, Recon Loss: 0.0014, VQ Loss: 0.0048
#
# --- Validation Complete --- Avg. Validation Loss: 0.0061
# Epoch [200/1000], Step [10/12], Total Loss: 0.0061, Recon Loss: 0.0014, VQ Loss: 0.0047
#
# --- Validation Complete --- Avg. Validation Loss: 0.0063
# Epoch [201/1000], Step [10/12], Total Loss: 0.0069, Recon Loss: 0.0022, VQ Loss: 0.0047
#
# --- Validation Complete --- Avg. Validation Loss: 0.0067
# Epoch [202/1000], Step [10/12], Total Loss: 0.0061, Recon Loss: 0.0016, VQ Loss: 0.0045
#
# --- Validation Complete --- Avg. Validation Loss: 0.0060
# Checkpoint saved to vqvcae_best_model.pth at Epoch 202
# ✅ Saved Best Model with Val Loss: 0.0060
# Epoch [203/1000], Step [10/12], Total Loss: 0.0058, Recon Loss: 0.0013, VQ Loss: 0.0045
#
# --- Validation Complete --- Avg. Validation Loss: 0.0058
# Checkpoint saved to vqvcae_best_model.pth at Epoch 203
# ✅ Saved Best Model with Val Loss: 0.0058
# Epoch [204/1000], Step [10/12], Total Loss: 0.0058, Recon Loss: 0.0013, VQ Loss: 0.0045
#
# --- Validation Complete --- Avg. Validation Loss: 0.0058
# Checkpoint saved to vqvcae_best_model.pth at Epoch 204
# ✅ Saved Best Model with Val Loss: 0.0058
# Epoch [205/1000], Step [10/12], Total Loss: 0.0056, Recon Loss: 0.0012, VQ Loss: 0.0044
#
# --- Validation Complete --- Avg. Validation Loss: 0.0056
# Checkpoint saved to vqvcae_best_model.pth at Epoch 205
# ✅ Saved Best Model with Val Loss: 0.0056
# Epoch [206/1000], Step [10/12], Total Loss: 0.0056, Recon Loss: 0.0012, VQ Loss: 0.0044
#
# --- Validation Complete --- Avg. Validation Loss: 0.0056
# Checkpoint saved to vqvcae_best_model.pth at Epoch 206
# ✅ Saved Best Model with Val Loss: 0.0056
# Epoch [207/1000], Step [10/12], Total Loss: 0.0058, Recon Loss: 0.0014, VQ Loss: 0.0044
#
# --- Validation Complete --- Avg. Validation Loss: 0.0060
# Epoch [208/1000], Step [10/12], Total Loss: 0.0073, Recon Loss: 0.0031, VQ Loss: 0.0042
#
# --- Validation Complete --- Avg. Validation Loss: 0.0059
# Epoch [209/1000], Step [10/12], Total Loss: 0.0056, Recon Loss: 0.0014, VQ Loss: 0.0042
#
# --- Validation Complete --- Avg. Validation Loss: 0.0057
# Epoch [210/1000], Step [10/12], Total Loss: 0.0056, Recon Loss: 0.0013, VQ Loss: 0.0042
#
# --- Validation Complete --- Avg. Validation Loss: 0.0054
# Checkpoint saved to vqvcae_best_model.pth at Epoch 210
# ✅ Saved Best Model with Val Loss: 0.0054
# Epoch [211/1000], Step [10/12], Total Loss: 0.0054, Recon Loss: 0.0013, VQ Loss: 0.0041
#
# --- Validation Complete --- Avg. Validation Loss: 0.0053
# Checkpoint saved to vqvcae_best_model.pth at Epoch 211
# ✅ Saved Best Model with Val Loss: 0.0053
# Epoch [212/1000], Step [10/12], Total Loss: 0.0053, Recon Loss: 0.0013, VQ Loss: 0.0041
#
# --- Validation Complete --- Avg. Validation Loss: 0.0053
# Epoch [213/1000], Step [10/12], Total Loss: 0.0053, Recon Loss: 0.0013, VQ Loss: 0.0040
#
# --- Validation Complete --- Avg. Validation Loss: 0.0053
# Checkpoint saved to vqvcae_best_model.pth at Epoch 213
# ✅ Saved Best Model with Val Loss: 0.0053
# Epoch [214/1000], Step [10/12], Total Loss: 0.0052, Recon Loss: 0.0013, VQ Loss: 0.0040
#
# --- Validation Complete --- Avg. Validation Loss: 0.0052
# Checkpoint saved to vqvcae_best_model.pth at Epoch 214
# ✅ Saved Best Model with Val Loss: 0.0052
# Epoch [215/1000], Step [10/12], Total Loss: 0.0053, Recon Loss: 0.0014, VQ Loss: 0.0039
#
# --- Validation Complete --- Avg. Validation Loss: 0.0055
# Epoch [216/1000], Step [10/12], Total Loss: 0.0064, Recon Loss: 0.0025, VQ Loss: 0.0039
#
# --- Validation Complete --- Avg. Validation Loss: 0.0055
# Epoch [217/1000], Step [10/12], Total Loss: 0.0052, Recon Loss: 0.0014, VQ Loss: 0.0038
#
# --- Validation Complete --- Avg. Validation Loss: 0.0053
# Epoch [218/1000], Step [10/12], Total Loss: 0.0060, Recon Loss: 0.0021, VQ Loss: 0.0039
#
# --- Validation Complete --- Avg. Validation Loss: 0.0054
# Epoch [219/1000], Step [10/12], Total Loss: 0.0052, Recon Loss: 0.0013, VQ Loss: 0.0039
#
# --- Validation Complete --- Avg. Validation Loss: 0.0051
# Checkpoint saved to vqvcae_best_model.pth at Epoch 219
# ✅ Saved Best Model with Val Loss: 0.0051
# Epoch [220/1000], Step [10/12], Total Loss: 0.0051, Recon Loss: 0.0012, VQ Loss: 0.0038
#
# --- Validation Complete --- Avg. Validation Loss: 0.0050
# Checkpoint saved to vqvcae_best_model.pth at Epoch 220
# ✅ Saved Best Model with Val Loss: 0.0050
# Epoch [221/1000], Step [10/12], Total Loss: 0.0051, Recon Loss: 0.0013, VQ Loss: 0.0038
#
# --- Validation Complete --- Avg. Validation Loss: 0.0050
# Checkpoint saved to vqvcae_best_model.pth at Epoch 221
# ✅ Saved Best Model with Val Loss: 0.0050
# Epoch [222/1000], Step [10/12], Total Loss: 0.0049, Recon Loss: 0.0012, VQ Loss: 0.0037
#
# --- Validation Complete --- Avg. Validation Loss: 0.0050
# Checkpoint saved to vqvcae_best_model.pth at Epoch 222
# ✅ Saved Best Model with Val Loss: 0.0050
# Epoch [223/1000], Step [10/12], Total Loss: 0.0051, Recon Loss: 0.0013, VQ Loss: 0.0037
#
# --- Validation Complete --- Avg. Validation Loss: 0.0049
# Checkpoint saved to vqvcae_best_model.pth at Epoch 223
# ✅ Saved Best Model with Val Loss: 0.0049
# Epoch [224/1000], Step [10/12], Total Loss: 0.0049, Recon Loss: 0.0012, VQ Loss: 0.0037
#
# --- Validation Complete --- Avg. Validation Loss: 0.0049
# Checkpoint saved to vqvcae_best_model.pth at Epoch 224
# ✅ Saved Best Model with Val Loss: 0.0049
# Epoch [225/1000], Step [10/12], Total Loss: 0.0053, Recon Loss: 0.0015, VQ Loss: 0.0037
#
# --- Validation Complete --- Avg. Validation Loss: 0.0051
# Epoch [226/1000], Step [10/12], Total Loss: 0.0049, Recon Loss: 0.0013, VQ Loss: 0.0036
#
# --- Validation Complete --- Avg. Validation Loss: 0.0050
# Epoch [227/1000], Step [10/12], Total Loss: 0.0054, Recon Loss: 0.0018, VQ Loss: 0.0036
#
# --- Validation Complete --- Avg. Validation Loss: 0.0054
# Epoch [228/1000], Step [10/12], Total Loss: 0.0048, Recon Loss: 0.0012, VQ Loss: 0.0036
#
# --- Validation Complete --- Avg. Validation Loss: 0.0048
# Checkpoint saved to vqvcae_best_model.pth at Epoch 228
# ✅ Saved Best Model with Val Loss: 0.0048
# Epoch [229/1000], Step [10/12], Total Loss: 0.0048, Recon Loss: 0.0012, VQ Loss: 0.0036
#
# --- Validation Complete --- Avg. Validation Loss: 0.0049
# Epoch [230/1000], Step [10/12], Total Loss: 0.0061, Recon Loss: 0.0025, VQ Loss: 0.0036
#
# --- Validation Complete --- Avg. Validation Loss: 0.0059
# Epoch [231/1000], Step [10/12], Total Loss: 0.0051, Recon Loss: 0.0016, VQ Loss: 0.0035
#
# --- Validation Complete --- Avg. Validation Loss: 0.0048
# Checkpoint saved to vqvcae_best_model.pth at Epoch 231
# ✅ Saved Best Model with Val Loss: 0.0048
# Epoch [232/1000], Step [10/12], Total Loss: 0.0047, Recon Loss: 0.0012, VQ Loss: 0.0035
#
# --- Validation Complete --- Avg. Validation Loss: 0.0047
# Checkpoint saved to vqvcae_best_model.pth at Epoch 232
# ✅ Saved Best Model with Val Loss: 0.0047
# Epoch [233/1000], Step [10/12], Total Loss: 0.0046, Recon Loss: 0.0011, VQ Loss: 0.0034
#
# --- Validation Complete --- Avg. Validation Loss: 0.0046
# Checkpoint saved to vqvcae_best_model.pth at Epoch 233
# ✅ Saved Best Model with Val Loss: 0.0046
# Epoch [234/1000], Step [10/12], Total Loss: 0.0046, Recon Loss: 0.0012, VQ Loss: 0.0034
#
# --- Validation Complete --- Avg. Validation Loss: 0.0047
# Epoch [235/1000], Step [10/12], Total Loss: 0.0048, Recon Loss: 0.0014, VQ Loss: 0.0033
#
# --- Validation Complete --- Avg. Validation Loss: 0.0048
# Epoch [236/1000], Step [10/12], Total Loss: 0.0044, Recon Loss: 0.0011, VQ Loss: 0.0033
#
# --- Validation Complete --- Avg. Validation Loss: 0.0046
# Checkpoint saved to vqvcae_best_model.pth at Epoch 236
# ✅ Saved Best Model with Val Loss: 0.0046
# Epoch [237/1000], Step [10/12], Total Loss: 0.0046, Recon Loss: 0.0014, VQ Loss: 0.0033
#
# --- Validation Complete --- Avg. Validation Loss: 0.0047
# Epoch [238/1000], Step [10/12], Total Loss: 0.0046, Recon Loss: 0.0013, VQ Loss: 0.0033
#
# --- Validation Complete --- Avg. Validation Loss: 0.0045
# Checkpoint saved to vqvcae_best_model.pth at Epoch 238
# ✅ Saved Best Model with Val Loss: 0.0045
# Epoch [239/1000], Step [10/12], Total Loss: 0.0044, Recon Loss: 0.0012, VQ Loss: 0.0032
#
# --- Validation Complete --- Avg. Validation Loss: 0.0044
# Checkpoint saved to vqvcae_best_model.pth at Epoch 239
# ✅ Saved Best Model with Val Loss: 0.0044
# Epoch [240/1000], Step [10/12], Total Loss: 0.0050, Recon Loss: 0.0018, VQ Loss: 0.0032
#
# --- Validation Complete --- Avg. Validation Loss: 0.0057
# Epoch [241/1000], Step [10/12], Total Loss: 0.0051, Recon Loss: 0.0020, VQ Loss: 0.0032
#
# --- Validation Complete --- Avg. Validation Loss: 0.0051
# Epoch [242/1000], Step [10/12], Total Loss: 0.0045, Recon Loss: 0.0014, VQ Loss: 0.0031
#
# --- Validation Complete --- Avg. Validation Loss: 0.0045
# Epoch [243/1000], Step [10/12], Total Loss: 0.0043, Recon Loss: 0.0012, VQ Loss: 0.0031
#
# --- Validation Complete --- Avg. Validation Loss: 0.0044
# Checkpoint saved to vqvcae_best_model.pth at Epoch 243
# ✅ Saved Best Model with Val Loss: 0.0044
# Epoch [244/1000], Step [10/12], Total Loss: 0.0042, Recon Loss: 0.0012, VQ Loss: 0.0031
#
# --- Validation Complete --- Avg. Validation Loss: 0.0042
# Checkpoint saved to vqvcae_best_model.pth at Epoch 244
# ✅ Saved Best Model with Val Loss: 0.0042
# Epoch [245/1000], Step [10/12], Total Loss: 0.0041, Recon Loss: 0.0011, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0041
# Checkpoint saved to vqvcae_best_model.pth at Epoch 245
# ✅ Saved Best Model with Val Loss: 0.0041
# Epoch [246/1000], Step [10/12], Total Loss: 0.0042, Recon Loss: 0.0011, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0041
# Epoch [247/1000], Step [10/12], Total Loss: 0.0045, Recon Loss: 0.0016, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0048
# Epoch [248/1000], Step [10/12], Total Loss: 0.0046, Recon Loss: 0.0016, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0048
# Epoch [249/1000], Step [10/12], Total Loss: 0.0049, Recon Loss: 0.0019, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0045
# Epoch [250/1000], Step [10/12], Total Loss: 0.0043, Recon Loss: 0.0013, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0041
# Checkpoint saved to vqvcae_best_model.pth at Epoch 250
# ✅ Saved Best Model with Val Loss: 0.0041
# Epoch [251/1000], Step [10/12], Total Loss: 0.0040, Recon Loss: 0.0011, VQ Loss: 0.0029
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Checkpoint saved to vqvcae_best_model.pth at Epoch 251
# ✅ Saved Best Model with Val Loss: 0.0039
# Epoch [252/1000], Step [10/12], Total Loss: 0.0039, Recon Loss: 0.0011, VQ Loss: 0.0029
#
# --- Validation Complete --- Avg. Validation Loss: 0.0040
# Epoch [253/1000], Step [10/12], Total Loss: 0.0041, Recon Loss: 0.0011, VQ Loss: 0.0030
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Checkpoint saved to vqvcae_best_model.pth at Epoch 253
# ✅ Saved Best Model with Val Loss: 0.0039
# Epoch [254/1000], Step [10/12], Total Loss: 0.0041, Recon Loss: 0.0013, VQ Loss: 0.0028
#
# --- Validation Complete --- Avg. Validation Loss: 0.0043
# Epoch [255/1000], Step [10/12], Total Loss: 0.0042, Recon Loss: 0.0014, VQ Loss: 0.0028
#
# --- Validation Complete --- Avg. Validation Loss: 0.0041
# Epoch [256/1000], Step [10/12], Total Loss: 0.0041, Recon Loss: 0.0014, VQ Loss: 0.0027
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Epoch [257/1000], Step [10/12], Total Loss: 0.0038, Recon Loss: 0.0011, VQ Loss: 0.0027
#
# --- Validation Complete --- Avg. Validation Loss: 0.0038
# Checkpoint saved to vqvcae_best_model.pth at Epoch 257
# ✅ Saved Best Model with Val Loss: 0.0038
# Epoch [258/1000], Step [10/12], Total Loss: 0.0037, Recon Loss: 0.0011, VQ Loss: 0.0027
#
# --- Validation Complete --- Avg. Validation Loss: 0.0037
# Checkpoint saved to vqvcae_best_model.pth at Epoch 258
# ✅ Saved Best Model with Val Loss: 0.0037
# Epoch [259/1000], Step [10/12], Total Loss: 0.0038, Recon Loss: 0.0012, VQ Loss: 0.0026
#
# --- Validation Complete --- Avg. Validation Loss: 0.0040
# Epoch [260/1000], Step [10/12], Total Loss: 0.0048, Recon Loss: 0.0022, VQ Loss: 0.0026
#
# --- Validation Complete --- Avg. Validation Loss: 0.0042
# Epoch [261/1000], Step [10/12], Total Loss: 0.0039, Recon Loss: 0.0013, VQ Loss: 0.0026
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Epoch [262/1000], Step [10/12], Total Loss: 0.0036, Recon Loss: 0.0011, VQ Loss: 0.0025
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Checkpoint saved to vqvcae_best_model.pth at Epoch 262
# ✅ Saved Best Model with Val Loss: 0.0036
# Epoch [263/1000], Step [10/12], Total Loss: 0.0036, Recon Loss: 0.0011, VQ Loss: 0.0025
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Checkpoint saved to vqvcae_best_model.pth at Epoch 263
# ✅ Saved Best Model with Val Loss: 0.0036
# Epoch [264/1000], Step [10/12], Total Loss: 0.0038, Recon Loss: 0.0013, VQ Loss: 0.0025
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Epoch [265/1000], Step [10/12], Total Loss: 0.0037, Recon Loss: 0.0013, VQ Loss: 0.0025
#
# --- Validation Complete --- Avg. Validation Loss: 0.0038
# Epoch [266/1000], Step [10/12], Total Loss: 0.0040, Recon Loss: 0.0016, VQ Loss: 0.0024
#
# --- Validation Complete --- Avg. Validation Loss: 0.0040
# Epoch [267/1000], Step [10/12], Total Loss: 0.0036, Recon Loss: 0.0012, VQ Loss: 0.0024
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Checkpoint saved to vqvcae_best_model.pth at Epoch 267
# ✅ Saved Best Model with Val Loss: 0.0036
# Epoch [268/1000], Step [10/12], Total Loss: 0.0038, Recon Loss: 0.0014, VQ Loss: 0.0024
#
# --- Validation Complete --- Avg. Validation Loss: 0.0038
# Epoch [269/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0011, VQ Loss: 0.0024
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Checkpoint saved to vqvcae_best_model.pth at Epoch 269
# ✅ Saved Best Model with Val Loss: 0.0034
# Epoch [270/1000], Step [10/12], Total Loss: 0.0034, Recon Loss: 0.0010, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Checkpoint saved to vqvcae_best_model.pth at Epoch 270
# ✅ Saved Best Model with Val Loss: 0.0034
# Epoch [271/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0012, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Epoch [272/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0012, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Epoch [273/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0012, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Epoch [274/1000], Step [10/12], Total Loss: 0.0042, Recon Loss: 0.0019, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0039
# Epoch [275/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0013, VQ Loss: 0.0022
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Epoch [276/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0012, VQ Loss: 0.0022
#
# --- Validation Complete --- Avg. Validation Loss: 0.0035
# Epoch [277/1000], Step [10/12], Total Loss: 0.0044, Recon Loss: 0.0021, VQ Loss: 0.0023
#
# --- Validation Complete --- Avg. Validation Loss: 0.0044
# Epoch [278/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0013, VQ Loss: 0.0022
#
# --- Validation Complete --- Avg. Validation Loss: 0.0035
# Epoch [279/1000], Step [10/12], Total Loss: 0.0033, Recon Loss: 0.0011, VQ Loss: 0.0022
#
# --- Validation Complete --- Avg. Validation Loss: 0.0032
# Checkpoint saved to vqvcae_best_model.pth at Epoch 279
# ✅ Saved Best Model with Val Loss: 0.0032
# Epoch [280/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0010, VQ Loss: 0.0022
#
# --- Validation Complete --- Avg. Validation Loss: 0.0032
# Checkpoint saved to vqvcae_best_model.pth at Epoch 280
# ✅ Saved Best Model with Val Loss: 0.0032
# Epoch [281/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0010, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0032
# Epoch [282/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0011, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [283/1000], Step [10/12], Total Loss: 0.0034, Recon Loss: 0.0013, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [284/1000], Step [10/12], Total Loss: 0.0033, Recon Loss: 0.0012, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [285/1000], Step [10/12], Total Loss: 0.0035, Recon Loss: 0.0014, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Epoch [286/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0010, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0032
# Checkpoint saved to vqvcae_best_model.pth at Epoch 286
# ✅ Saved Best Model with Val Loss: 0.0032
# Epoch [287/1000], Step [10/12], Total Loss: 0.0031, Recon Loss: 0.0011, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0031
# Checkpoint saved to vqvcae_best_model.pth at Epoch 287
# ✅ Saved Best Model with Val Loss: 0.0031
# Epoch [288/1000], Step [10/12], Total Loss: 0.0031, Recon Loss: 0.0011, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0031
# Checkpoint saved to vqvcae_best_model.pth at Epoch 288
# ✅ Saved Best Model with Val Loss: 0.0031
# Epoch [289/1000], Step [10/12], Total Loss: 0.0031, Recon Loss: 0.0011, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [290/1000], Step [10/12], Total Loss: 0.0056, Recon Loss: 0.0035, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0052
# Epoch [291/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0012, VQ Loss: 0.0021
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Epoch [292/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0011, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0031
# Checkpoint saved to vqvcae_best_model.pth at Epoch 292
# ✅ Saved Best Model with Val Loss: 0.0031
# Epoch [293/1000], Step [10/12], Total Loss: 0.0031, Recon Loss: 0.0010, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Checkpoint saved to vqvcae_best_model.pth at Epoch 293
# ✅ Saved Best Model with Val Loss: 0.0030
# Epoch [294/1000], Step [10/12], Total Loss: 0.0029, Recon Loss: 0.0010, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0029
# Checkpoint saved to vqvcae_best_model.pth at Epoch 294
# ✅ Saved Best Model with Val Loss: 0.0029
# Epoch [295/1000], Step [10/12], Total Loss: 0.0030, Recon Loss: 0.0010, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [296/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0012, VQ Loss: 0.0020
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [297/1000], Step [10/12], Total Loss: 0.0034, Recon Loss: 0.0015, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Epoch [298/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0013, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0032
# Epoch [299/1000], Step [10/12], Total Loss: 0.0029, Recon Loss: 0.0010, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [300/1000], Step [10/12], Total Loss: 0.0029, Recon Loss: 0.0010, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0029
# Checkpoint saved to vqvcae_best_model.pth at Epoch 300
# ✅ Saved Best Model with Val Loss: 0.0029
# Epoch [301/1000], Step [10/12], Total Loss: 0.0029, Recon Loss: 0.0010, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0029
# Checkpoint saved to vqvcae_best_model.pth at Epoch 301
# ✅ Saved Best Model with Val Loss: 0.0029
# Epoch [302/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0013, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0034
# Epoch [303/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0013, VQ Loss: 0.0019
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [304/1000], Step [10/12], Total Loss: 0.0030, Recon Loss: 0.0011, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0029
# Checkpoint saved to vqvcae_best_model.pth at Epoch 304
# ✅ Saved Best Model with Val Loss: 0.0029
# Epoch [305/1000], Step [10/12], Total Loss: 0.0028, Recon Loss: 0.0009, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0028
# Checkpoint saved to vqvcae_best_model.pth at Epoch 305
# ✅ Saved Best Model with Val Loss: 0.0028
# Epoch [306/1000], Step [10/12], Total Loss: 0.0028, Recon Loss: 0.0010, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0028
# Epoch [307/1000], Step [10/12], Total Loss: 0.0030, Recon Loss: 0.0012, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [308/1000], Step [10/12], Total Loss: 0.0031, Recon Loss: 0.0013, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [309/1000], Step [10/12], Total Loss: 0.0029, Recon Loss: 0.0011, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [310/1000], Step [10/12], Total Loss: 0.0030, Recon Loss: 0.0012, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Checkpoint saved to vqvcae_best_model.pth at Epoch 310
# ✅ Saved Best Model with Val Loss: 0.0027
# Epoch [311/1000], Step [10/12], Total Loss: 0.0028, Recon Loss: 0.0010, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0031
# Epoch [312/1000], Step [10/12], Total Loss: 0.0050, Recon Loss: 0.0032, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0033
# Epoch [313/1000], Step [10/12], Total Loss: 0.0030, Recon Loss: 0.0013, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0029
# Epoch [314/1000], Step [10/12], Total Loss: 0.0027, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Checkpoint saved to vqvcae_best_model.pth at Epoch 314
# ✅ Saved Best Model with Val Loss: 0.0027
# Epoch [315/1000], Step [10/12], Total Loss: 0.0027, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0026
# Checkpoint saved to vqvcae_best_model.pth at Epoch 315
# ✅ Saved Best Model with Val Loss: 0.0026
# Epoch [316/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0026
# Checkpoint saved to vqvcae_best_model.pth at Epoch 316
# ✅ Saved Best Model with Val Loss: 0.0026
# Epoch [317/1000], Step [10/12], Total Loss: 0.0027, Recon Loss: 0.0010, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Epoch [318/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0010, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0026
# Checkpoint saved to vqvcae_best_model.pth at Epoch 318
# ✅ Saved Best Model with Val Loss: 0.0026
# Epoch [319/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0026
# Checkpoint saved to vqvcae_best_model.pth at Epoch 319
# ✅ Saved Best Model with Val Loss: 0.0026
# Epoch [320/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0026
# Epoch [321/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0010, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Epoch [322/1000], Step [10/12], Total Loss: 0.0059, Recon Loss: 0.0043, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0049
# Epoch [323/1000], Step [10/12], Total Loss: 0.0032, Recon Loss: 0.0014, VQ Loss: 0.0018
#
# --- Validation Complete --- Avg. Validation Loss: 0.0030
# Epoch [324/1000], Step [10/12], Total Loss: 0.0028, Recon Loss: 0.0011, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Epoch [325/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0009, VQ Loss: 0.0017
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Checkpoint saved to vqvcae_best_model.pth at Epoch 325
# ✅ Saved Best Model with Val Loss: 0.0025
# Epoch [326/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Checkpoint saved to vqvcae_best_model.pth at Epoch 326
# ✅ Saved Best Model with Val Loss: 0.0025
# Epoch [327/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Checkpoint saved to vqvcae_best_model.pth at Epoch 327
# ✅ Saved Best Model with Val Loss: 0.0025
# Epoch [328/1000], Step [10/12], Total Loss: 0.0027, Recon Loss: 0.0011, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0028
# Epoch [329/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0010, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Epoch [330/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Checkpoint saved to vqvcae_best_model.pth at Epoch 330
# ✅ Saved Best Model with Val Loss: 0.0025
# Epoch [331/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Checkpoint saved to vqvcae_best_model.pth at Epoch 331
# ✅ Saved Best Model with Val Loss: 0.0025
# Epoch [332/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Epoch [333/1000], Step [10/12], Total Loss: 0.0025, Recon Loss: 0.0009, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0025
# Epoch [334/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0010, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0027
# Epoch [335/1000], Step [10/12], Total Loss: 0.0024, Recon Loss: 0.0009, VQ Loss: 0.0016
#
# --- Validation Complete --- Avg. Validation Loss: 0.0024
# Checkpoint saved to vqvcae_best_model.pth at Epoch 335
# ✅ Saved Best Model with Val Loss: 0.0024
# Epoch [336/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0010, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0028
# Epoch [337/1000], Step [10/12], Total Loss: 0.0047, Recon Loss: 0.0032, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0036
# Epoch [338/1000], Step [10/12], Total Loss: 0.0028, Recon Loss: 0.0013, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0028
# Epoch [339/1000], Step [10/12], Total Loss: 0.0026, Recon Loss: 0.0011, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0024
# Epoch [340/1000], Step [10/12], Total Loss: 0.0024, Recon Loss: 0.0009, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0024
# Checkpoint saved to vqvcae_best_model.pth at Epoch 340
# ✅ Saved Best Model with Val Loss: 0.0024
# Epoch [341/1000], Step [10/12], Total Loss: 0.0024, Recon Loss: 0.0009, VQ Loss: 0.0015
#
# --- Validation Complete --- Avg. Validation Loss: 0.0024
# ...
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [906/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [907/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [908/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [909/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [910/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [911/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [912/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [913/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [914/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 914
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [915/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 915
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [916/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 916
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [917/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [918/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [919/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [920/1000], Step [10/12], Total Loss: 0.0012, Recon Loss: 0.0009, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0009
# Epoch [921/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [922/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [923/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 923
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [924/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 924
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [925/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [926/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 926
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [927/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [928/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [929/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [930/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [931/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [932/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [933/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [934/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [935/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [936/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [937/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 937
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [938/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [939/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0009
# Epoch [940/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [941/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [942/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [943/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [944/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 944
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [945/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 945
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [946/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [947/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0006, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0011
# Epoch [948/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [949/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [950/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [951/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [952/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 952
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [953/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 953
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [954/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [955/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [956/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [957/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [958/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [959/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [960/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [961/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [962/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 962
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [963/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [964/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [965/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [966/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [967/1000], Step [10/12], Total Loss: 0.0010, Recon Loss: 0.0008, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0010
# Epoch [968/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [969/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 969
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [970/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 970
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [971/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [972/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [973/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [974/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [975/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [976/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [977/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [978/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [979/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [980/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [981/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [982/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [983/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [984/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 984
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [985/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [986/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [987/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [988/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [989/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [990/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 990
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [991/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [992/1000], Step [10/12], Total Loss: 0.0008, Recon Loss: 0.0005, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0008
# Epoch [993/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [994/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [995/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [996/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [997/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [998/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Epoch [999/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 999
# ✅ Saved Best Model with Val Loss: 0.0007
# Epoch [1000/1000], Step [10/12], Total Loss: 0.0007, Recon Loss: 0.0004, VQ Loss: 0.0003
#
# --- Validation Complete --- Avg. Validation Loss: 0.0007
# Checkpoint saved to vqvcae_best_model.pth at Epoch 1000
# ✅ Saved Best Model with Val Loss: 0.0007
# Training finished. 🎉
#
# ==================================================
# RUNNING FINAL TEST EVALUATION
# ==================================================
# Loaded best model saved at epoch 1000.
#
# ==================================================
# FINAL TEST RESULT: Avg. Test Loss: 0.0007
# ==================================================

# %%
model.eval()
from torchvision.transforms import v2

# Use the same transforms as training:
transform = v2.Compose([
    TopCrop(350),
    v2.Grayscale(num_output_channels=1),
    v2.Resize((128, 128)),
    v2.ColorJitter(contrast=(2.0, 2.0)), # If used during training
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True)
])

# Assume 'pil_image' is your single input image (e.g., loaded via PIL.Image.open)
pil_image = Image.open("alu.png")

# 1. Apply the transformation
transformed_image = transform(pil_image) # Shape: [1, 128, 128] (C, H, W)

# 2. Add the Batch Dimension (B=1)
# The model expects a 4D tensor (Batch, Channels, Height, Width)
input_tensor = transformed_image.unsqueeze(0) # Shape: [1, 1, 128, 128]

# 3. Move the tensor to the correct device
input_tensor = input_tensor.to(device)

plt.imshow(transformed_image.permute(1, 2, 0).numpy().squeeze(), cmap="gray")

# %%
with torch.no_grad():
    # Run the single 4D tensor through the model
    reconstructed_tensor, vq_loss, indices = model(input_tensor)

# The output tensor 'reconstructed_tensor' will have the shape [1, 1, 128, 128]

# --- Post-Processing the Output ---

# 1. Remove the Batch Dimension
reconstructed_image = reconstructed_tensor.squeeze(0) # Shape: [1, 128, 128]

# 2. Move back to CPU (required for visualization/saving)
reconstructed_image = reconstructed_image.cpu()

# 3. Convert to NumPy Array (optional, for visualization tools like matplotlib)
# This removes the channel dimension for grayscale (1, 128, 128) -> (128, 128)
import numpy as np
output_for_display = reconstructed_image.permute(1, 2, 0).numpy().squeeze() 

# You can now display the original image and the reconstructed image:
plt.imshow(output_for_display, cmap='gray')

# %%
recon_image = reconstructed_image.numpy().squeeze()
original_image = transformed_image.numpy().squeeze()

error_map = np.square(original_image - recon_image) 

# --- 3. Calculate Overall Anomaly Score (Optional) ---

# The final anomaly score for the entire image is usually the sum or mean of the error map
anomaly_score = np.sum(error_map) # or np.mean(error_map)
print(f"Total Anomaly Score for Image: {anomaly_score:.4f}")

plt.imshow(error_map, cmap='gray')
# Out:
# Total Anomaly Score for Image: 114.6390
